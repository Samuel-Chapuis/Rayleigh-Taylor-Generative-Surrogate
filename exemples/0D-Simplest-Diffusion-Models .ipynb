# %%
import matplotlib.pyplot as plt
import matplotlib as mpl
import pandas as pd
import numpy as np
import torch
import seaborn as sns
import itertools
from tqdm.auto import tqdm

COLORS = ["#1f77b4", "#f54f4c"]

# %%
import matplotlib.pyplot as plt

REPORT_PLOT_STYLE = {
    "font.size": 14,
    "axes.titlesize": 16,
    "axes.labelsize": 15,
    "xtick.labelsize": 13,
    "ytick.labelsize": 13,
    "legend.fontsize": 13,
    "figure.titlesize": 18,
}
plt.rcParams.update(REPORT_PLOT_STYLE)

# %% [markdown]
# # Simplest Implementation of Diffusion Models
#
# **Source:** [Tutoriel de Emilo's blog](https://e-dorigatti.github.io/math/deep%20learning/2023/06/25/diffusion.html)
#
# Diffusion refers to the gradual corruption of training examples by repeatedly adding a small amount of noise, mimicking the way heat diffuses through a material until it reaches an uniform temperature. After a few hundreds or thousands of noise diffusion steps, the information in the original sample is completely lost, such that the result is indistinguishable from the Gaussian that we will use as a starting point to generate new samples. Figure 2 from the paper (Ho, 2020) demonstrates this process graphically:
#
# ![Texte alternatif](ressources/diffusion.png "Titre de l'image")
#
# Here, $x_0$ is the original sample, the image of a guy, and the process of adding noise is represented by the dashed arrow going from right to left, so that, after $T$ steps, only noise remains in $x_T$. The generative process is represented by the arrows going from left to right, from $x_T$ to $x_0$, and the generative model is denoted by $p_\theta$, while the noise-adding process is $q$.
#
# In this tutorial, we will learn to generate samples from a very simple unidimensional distribution, so that we can easily visualize the generative process. Let’s start by generating some data:

# %% [markdown]
# # Création du Dataset
#
# > torch.distributions.Categorical(torch.tensor([1, 2]))
#
# Définie 2 variable aléatoire discrete choisit entre K catégorie (ici K=2)
# Avec le tenseur [1, 2] les poids sont alors,
# $$ \pi_1 = \frac{1}{1+2}=\frac{1}{3} \quad \pi_2 = \frac{2}{1+2}=\frac{2}{3} $$
#
# > torch.distributions.Normal(torch.tensor([-4., 4.]), torch.tensor([1., 1.]))
#
# Définie 2 lois normales definie par des tenseurs
# $$ \mathcal{N}( \mu_1=-4, \sigma_1=1) \quad \mathcal{N}(\mu_2=4, \sigma_2=1) $$
#
# > data_distribution = torch.distributions.mixture_same_family.MixtureSameFamily
#
# Permet de mélanger ces distributions de sorte a avoir,
# $$ q(x_0) = \sum_{k=1}^{K} \pi_k \cdot \mathcal{N}(x|\mu_k,\sigma_k)

# %%
data_distribution = torch.distributions.mixture_same_family.MixtureSameFamily(
    torch.distributions.Categorical(torch.tensor([1, 2])),
    torch.distributions.Normal(torch.tensor([-4., 4.]), torch.tensor([1., 1.]))
)

dataset = data_distribution.sample(torch.Size([1000, 1]))

# %%
fig, ax = plt.subplots(2, 1, figsize=(10, 5), sharex=True)

# --- ax[0] : la vraie densité (PDF) ---
x = torch.linspace(-10, 10, 500)                # grille de 500 points entre -10 et 10
pdf = data_distribution.log_prob(x).exp()       # p(x) = exp(log p(x)), car torch donne toujour le log de la proba 
ax[0].plot(x.numpy(), pdf.numpy(), color=COLORS[0])
ax[0].set_title('Distribution théorique vs échantillons')
ax[0].set_ylabel("p(x)")

# --- ax[1] : histogramme des échantillons ---
ax[1].hist(dataset, bins=50, density=True, color=COLORS[1], alpha=0.7) # bins : nombre de barres de l'histograme
# density=True normalise l'histogramme pour que l'aire = 1,
# ce qui le rend comparable à la PDF du dessus
ax[1].set_xlabel("x")
ax[1].set_ylabel("fréquence")

fig.subplots_adjust(hspace=0)
plt.show()

# %% [markdown]
# ## Diffusion Process
#
# Equation du processus de diffusion foward:
# $$q(x_{1:T} | x_0) := \prod_{t=1}^{T} q(x_t | x_{t-1})$$
# Le processus de diffusion est une chaîne de Markov : pour simuler toute la trajectoire du bruit, il suffit d'appliquer T petites étapes successives et indépendantes, chacune ajoutant un peu de bruit à partir de l'état précédent.
# Ces étapes d'ajouts s'écrivent comme,
# $$ q(x_t | x_{t-1}) := \mathcal{N}(x_t|\sqrt{1-\beta_t} \, x_{t-1};\beta_t \textbf{I}) $$
# Ou la moyenne et la variances sont choisi de tel sorte que la sortie de la distribution pour $x_T$ ai une moyenne nulle et une variance unitaire. Et $\beta$ est la quantité de bruit ajouté a chaque étape.

# %%
# Parametres
TIME_STEPS = 250
BETA = 0.02

# %%
def do_diffusion(data, steps=100, beta=0.02):
    """_summary_
    Perform diffusion following equation 1 in diffusion process

    Args:
        data (_type_): Data to apply diffusion on
        steps (int, optional): number of add noise iteration. Defaults to TIME_STEPS.
        beta (float, optional): how much noise is added at each step. Defaults to BETA.

    Returns:
        list: (x(t)) and x(t)
    """
    distributions, samples = [None], [data]
    xt = data
    for t in range(steps):
        q = torch.distributions.Normal(
            np.sqrt(1 - beta) * xt,
            np.sqrt(beta)
        )
        xt = q.sample()

        distributions.append(q)
        samples.append(xt)

    return distributions, samples

# %%
_, samples = do_diffusion(dataset, TIME_STEPS, BETA)

# %%
fig, ax = plt.subplots(1, 1, figsize=(7, 7), sharex=True)
for t in torch.stack(samples)[:, :, 0].T[:100]:
    ax.plot(t, c='firebrick', alpha=0.1)

ax.set_xlabel('Diffusion time')
ax.set_ylabel('Data')
ax.set_title('Diffusion process')
# Out:
# Text(0.5, 1.0, 'Diffusion process')

# %%
fig, ax = plt.subplots(1, 2, figsize=(10, 5), sharex=True)

ax[0].hist(torch.stack(samples)[0, :, 0]
           , bins=50, density=True, color='coral', alpha=0.7)
ax[0].set_xlabel("x")
ax[0].set_ylabel("fréquence")
ax[0].set_xlim(-8,8)
ax[0].set_title(f'Distribution initiale')


ax[1].hist(torch.stack(samples)[250, :, 0]
           , bins=50, density=True, color='firebrick', alpha=0.7)
ax[1].set_xlabel("x")
ax[1].set_xlim(-8,8)
ax[1].set_title(f'Distribution Bruitée')

plt.show()

# %% [markdown]
# **Version animé**

# %%
import matplotlib.animation as animation
from IPython.display import HTML


samples_tensor = torch.stack(samples)  # (T, N, dim)

fig, ax = plt.subplots(figsize=(6, 5))

def update(i):
    ax.clear()
    
    ax.hist(samples_tensor[i, :, 0],
            bins=50,
            density=True,
            color='coral',
            alpha=0.7)
    
    ax.set_xlim(-8, 8)
    ax.set_ylim(0, 0.6)  # ajuste selon tes données
    ax.set_title(f"Distribution à l'itération {i}")
    ax.set_xlabel("x")
    ax.set_ylabel("densité")

ani = animation.FuncAnimation(
    fig,
    update,
    frames=251,   # de 0 à 250
    interval=100  # ms entre frames
)

# ani.save("distribution.gif", writer="pillow", fps=10)
HTML(ani.to_jshtml())
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Microsoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_imge59ba05c09094060a0d35a197fdb97df">
#   <div class="anim-controls">
#     <input id="_anim_slidere59ba05c09094060a0d35a197fdb97df" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="anime59ba05c09094060a0d35a197fdb97df.set_frame(parseInt(this.value));">
#     <div class="anim-buttons">
#       <button title="Decrease speed" aria-label="Decrease speed" onclick="anime59ba05c09094060a0d35a197fdb97df.slower()">
#           <i class="fa fa-minus"></i></button>
#       <button title="First frame" aria-label="First frame" onclick="anime59ba05c09094060a0d35a197fdb97df.first_frame()">
#         <i class="fa fa-fast-backward"></i></button>
#       <button title="Previous frame" aria-label="Previous frame" onclick="anime59ba05c09094060a0d35a197fdb97df.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button title="Play backwards" aria-label="Play backwards" onclick="anime59ba05c09094060a0d35a197fdb97df.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button title="Pause" aria-label="Pause" onclick="anime59ba05c09094060a0d35a197fdb97df.pause_animation()">
#           <i class="fa fa-pause"></i></button>
#       <button title="Play" aria-label="Play" onclick="anime59ba05c09094060a0d35a197fdb97df.play_animation()">
#           <i class="fa fa-play"></i></button>
#       <button title="Next frame" aria-label="Next frame" onclick="anime59ba05c09094060a0d35a197fdb97df.next_frame()">
#           <i class="fa fa-step-forward"></i></button>
#       <button title="Last frame" aria-label="Last frame" onclick="anime59ba05c09094060a0d35a197fdb97df.last_frame()">
#           <i class="fa fa-fast-forward"></i></button>
#       <button title="Increase speed" aria-label="Increase speed" onclick="anime59ba05c09094060a0d35a197fdb97df.faster()">
#           <i class="fa fa-plus"></i></button>
#     </div>
#     <form title="Repetition mode" aria-label="Repetition mode" action="#n" name="_anim_loop_selecte59ba05c09094060a0d35a197fdb97df"
#           class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_e59ba05c09094060a0d35a197fdb97df"
#              >
#       <label for="_anim_radio1_e59ba05c09094060a0d35a197fdb97df">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_e59ba05c09094060a0d35a197fdb97df"
#              checked>
#       <label for="_anim_radio2_e59ba05c09094060a0d35a197fdb97df">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_e59ba05c09094060a0d35a197fdb97df"
#              >
#       <label for="_anim_radio3_e59ba05c09094060a0d35a197fdb97df">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_imge59ba05c09094060a0d35a197fdb97df";
#     var slider_id = "_anim_slidere59ba05c09094060a0d35a197fdb97df";
#     var loop_select_id = "_anim_loop_selecte59ba05c09094060a0d35a197fdb97df";
#     var frames = new Array(251);
#
#   frames[0] = "...\
# bGliIHZlcnNpb24zLjEwLjksIGh0dHBzOi8vbWF0cGxvdGxpYi5vcmcvJkbTWQAAAAlwSFlzAAAP\
# YQAAD2EBqD+naQAAN7VJ

# %% [markdown]
# **Remarque**
#
# On peut clairement voire sur les 2 plot précedent qu'en ajoutant graduellement du bruit on fait tendre la distribution initiale vers une loi Normale $\mathcal{N}(1;0)$

# %% [markdown]
# # Entrainement
# On se place dans un cas tres simple, ou le modele de diffusion en degradant d'abord les données d'exemple, puis essaye de les reconstruire depuis un exemple moins bruité, a chaque étape du processus de degradation.
# La loss utilisé ici sera un maximum de vraissemblance ("upper bound on the negative log likelihood" en anglais),
# $$ L := \mathbb{E}_q \left[ - \log p(x_T) - \sum_{t=1}^{T} \log \frac{p_\theta(x_{t-1} \mid x_t)}{q(x_t \mid x_{t-1})} \right] $$
# Ou la sortie du modele generatif ( probleme inverse ) a la forme de,
# $$ q(x_t | x_{t-1}) := \mathcal{N}(x_{t-1};\mu_{\theta}(x,t),\Sigma_{\theta}(x_t,t)) $$
#
# Il est important de voir qu'ici on entraine 2 réseaux de neuronnes, $\mu_\theta$ et $\Sigma_\theta$ prennant comme entré un échantillon bruité $x_t$ a une itération t, et essayant de predire les parametre de la distribution de l'echantillon $x_{t-1}$.
#
# Intuitivement on entraine ces reseaux a prédire $x_{t-1}$ basé sur $x_t$, a savoir le terme $p_\theta(x_{t-1} \mid x_t)$ dans la loss, pour chaque étape de diffusion.
#
# Les autres élement de la loss sont ici des élement théorique $q(x_{t-1} \mid x_t)$ assurant que la loss puisse devenir parfaitement nulle pour ce cas spécifique de 2 gaussiennes

# %%
def compute_loss(forward_distributions, forward_samples, mean_model, var_model):
    """
    Calcule la loos en approximant la divergence entre le processus forward (q) et le
    processus reverse appris (p).

    Args:
        forward_distributions (list of torch.distributions.Distribution):
            Liste des distributions q(x_t | x_{t-1}) pour chaque pas de temps.
        forward_samples (list of torch.Tensor):
            Liste des échantillons générés par le processus forward,
            de taille T, où chaque élément est de shape (batch_size, dim).
        mean_model (torch.nn.Module):
            Modèle neuronal prédisant la moyenne du processus inverse p(x_{t-1} | x_t).
        var_model (torch.nn.Module):
            Modèle neuronal prédisant l'écart-type (ou variance) du processus inverse.

    Returns:
        torch.Tensor:
            Scalaire représentant la loss moyenne sur tous les pas de temps.
    """

    # ------------------------------
    # Terme de loss pour x(T)
    # On impose que x_T suive une loi normale centrée réduite
    # ------------------------------
    p = torch.distributions.Normal(
        torch.zeros(forward_samples[0].shape),
        torch.ones(forward_samples[0].shape)
    )

    # log-vraisemblance négative de x_T
    loss = -p.log_prob(forward_samples[-1]).mean()

    # ------------------------------
    # Boucle sur les pas de temps
    # ------------------------------
    for t in range(1, len(forward_samples)):

        xt = forward_samples[t]         # état courant x(t)
        xprev = forward_samples[t - 1]  # état précédent x(t-1)
        q = forward_distributions[t]    # distribution forward q(x_t | x_{t-1})

        # ------------------------------
        # Préparation de l'entrée des réseaux
        # On ajoute le temps t normalisé comme feature supplémentaire
        # ------------------------------
        xin = torch.cat(
            (
                xt,
                (t / len(forward_samples)) * torch.ones(xt.shape[0], 1)
            ),
            dim=1
        )

        # ------------------------------
        # Modélisation du processus inverse p(x_{t-1} | x_t)
        # ------------------------------
        mu = mean_model(xin)      # moyenne prédite
        sigma = var_model(xin)    # écart-type prédit

        p = torch.distributions.Normal(mu, sigma)

        # ------------------------------
        # Contribution à la loss
        # ------------------------------

        # terme de vraisemblance du modèle inverse
        loss -= torch.mean(p.log_prob(xprev))

        # terme du processus forward (constant si q fixé, mais utile pour formulation ELBO)
        loss += torch.mean(q.log_prob(xt))

    # ------------------------------
    # Normalisation par le nombre de pas de temps
    # ------------------------------
    return loss / len(forward_samples)

# %%
mean_model = torch.nn.Sequential(
    torch.nn.Linear(2, 4), torch.nn.ReLU(),
    torch.nn.Linear(4, 1)
)
var_model = torch.nn.Sequential(
    torch.nn.Linear(2, 4), torch.nn.ReLU(),
    torch.nn.Linear(4, 1), torch.nn.Softplus()
)

# %%
optim = torch.optim.AdamW(
    itertools.chain(mean_model.parameters(), var_model.parameters()),
    lr=1e-2, weight_decay=1e-6,
)

# %%
loss_history = []
bar = tqdm(range(1000))
for e in bar:
    forward_distributions, forward_samples = do_diffusion(dataset, TIME_STEPS, BETA)
    optim.zero_grad()
    loss = compute_loss(
        forward_distributions, forward_samples, mean_model, var_model
    )
    loss.backward()
    optim.step()

    bar.set_description(f'Loss: {loss.item():.4f}')
    loss_history.append(loss.item())
# Out:
# Loss: 0.0099: 100%|██████████| 1000/1000 [07:22<00:00,  2.26it/s]

# %%
fig, ax = plt.subplots(1, 1, figsize=(7, 7), sharex=True)
ax.plot(loss_history)
ax.set_yscale('log')
ax.set_ylabel('Loss')
ax.set_xlabel('Ittérations')
ax.set_title('Loss Fonction')
plt.show()

# %% [markdown]
# # Géneration de données

# %%
def sample_reverse(mean_model, var_model, count, steps=TIME_STEPS):
    p = torch.distributions.Normal(torch.zeros(count, 1), torch.ones(count, 1))
    xt = p.sample()
    sample_history = [xt]
    for t in range(steps, 0, -1):
        xin = torch.cat((xt, t * torch.ones(xt.shape) / steps), dim=1)
        p = torch.distributions.Normal(
            mean_model(xin), var_model(xin)
        )
        xt = p.sample()
        sample_history.append(xt)
    return sample_history

# %%
samps = torch.stack(sample_reverse(mean_model, var_model, 1000))

# %%
plt.rcParams.update({
    "font.size": 10,
    "axes.titlesize": 11,
    "axes.labelsize": 10,
    "xtick.labelsize": 9,
    "ytick.labelsize": 9,
    "figure.dpi": 150,
})

fig, ax = plt.subplots(1, 2, figsize=(12, 4), constrained_layout=True)

# LEFT: HISTOGRAMS
ax[0].hist(dataset, bins=50, density=True,
           color='coral', alpha=0.5, label="Dataset")

ax[0].hist(samps[-1, :, 0], bins=50, density=True,
           color='tab:blue', alpha=0.5, label="Generated")

ax[0].set_title("Distribution comparison")
ax[0].set_xlabel("x")
ax[0].set_ylabel("Density")
ax[0].legend(frameon=False)

# RIGHT: TRAJECTORIES
for t in samps[:, :, 0].T[:100]:
    ax[1].plot(t,
               color='navy' if t[-1] <= 0 else 'blueviolet',
               alpha=0.08,
               linewidth=0.8)

ax[1].set_title("Generation trajectories")
ax[1].set_xlabel("Time step")
ax[1].set_ylabel("Value")

# Optionnel: grille légère style paper
for a in ax:
    a.grid(True, linestyle='--', linewidth=0.5, alpha=0.3)
    a.spines['top'].set_visible(False)
    a.spines['right'].set_visible(False)

plt.show()

# %% [markdown]
# ## Figures propres pour le rapport
#
# Les figures ci-dessous reprennent l'exemple 1D du notebook sous une forme plus lisible pour le rapport. La couleur devient plus intense quand le pas de temps augmente : les ?tats proches de $x_0$ sont clairs, et les ?tats proches de $x_T$ sont plus fonc?s.

# %%
from pathlib import Path
from matplotlib.collections import LineCollection
from matplotlib import colors as mcolors

REPORT_FIG_DIR = Path("doc/BDRPReportTemplate/figures/ch3")
if not REPORT_FIG_DIR.exists():
    REPORT_FIG_DIR = Path("../doc/BDRPReportTemplate/figures/ch3")
REPORT_FIG_DIR.mkdir(parents=True, exist_ok=True)

rng = np.random.default_rng(8)
weights = np.array([1 / 3, 2 / 3])
means = np.array([-4.0, 4.0])
sigmas = np.array([1.0, 1.0])
beta = 0.02
T = 250
x_grid = np.linspace(-9, 9, 1000)

plt.rcParams.update(REPORT_PLOT_STYLE)

def normal_pdf(x, mu, sigma):
    return np.exp(-0.5 * ((x - mu) / sigma) ** 2) / (sigma * np.sqrt(2 * np.pi))

def mixture_pdf(x, t=0):
    alpha_bar = (1 - beta) ** t
    noisy_means = np.sqrt(alpha_bar) * means
    noisy_vars = alpha_bar * sigmas**2 + (1 - alpha_bar)
    pdf = np.zeros_like(x)
    for w, m, v in zip(weights, noisy_means, noisy_vars):
        pdf += w * normal_pdf(x, m, np.sqrt(v))
    return pdf

def sample_mixture(n):
    comp = rng.choice(2, size=n, p=weights)
    return rng.normal(means[comp], sigmas[comp])

def time_color(t, cmap_name="Reds"):
    # t=0: couleur claire et peu intense; t=T: couleur sombre et satur?e.
    return plt.get_cmap(cmap_name)(0.25 + 0.70 * (t / T))

def time_color_r(t, cmap_name="Reds_r"):
    # t=0: couleur claire et peu intense; t=T: couleur sombre et satur?e.
    return plt.get_cmap(cmap_name)(0.25 + 0.70 * (t / T))

def style_axes(ax):
    ax.grid(True, linestyle="--", linewidth=0.5, alpha=0.3)
    ax.spines["top"].set_visible(False)
    ax.spines["right"].set_visible(False)

# %% [markdown]
# ### Distribution de d?part

# %%
x0_samples = sample_mixture(3000)

fig, ax = plt.subplots(figsize=(6.6, 3.6), constrained_layout=True)
ax.hist(x0_samples, bins=55, density=True, color="#d95745", alpha=0.45, label="Samples")
ax.plot(x_grid, mixture_pdf(x_grid, 0), color="#1f5a85", linewidth=2.2, label="Target density")
ax.set_xlabel(r"$x_0$")
ax.set_ylabel("Density")
ax.set_title("One-dimensional training distribution")
ax.set_xlim(-8, 8)
ax.legend(frameon=False)
style_axes(ax)
fig.savefig(REPORT_FIG_DIR / "diffusion_1d_dataset.png", bbox_inches="tight")
plt.show()

# %% [markdown]
# ### Processus forward avec intensit? croissante

# %%
fig, axes = plt.subplots(1, 2, figsize=(10.2, 4.0), constrained_layout=True)
steps = [0, 25, 75, 150, 250]

for t in steps:
    axes[0].plot(
        x_grid,
        mixture_pdf(x_grid, t),
        color=time_color(t),
        linewidth=1.2 + 1.4 * (t / T),
        alpha=0.45 + 0.55 * (t / T),
        label=fr"$t={t}$",
    )
axes[0].plot(x_grid, normal_pdf(x_grid, 0, 1), color="black", linewidth=1.1,
             linestyle=":", label=r"$\mathcal{N}(0,1)$")
axes[0].set_xlabel(r"$x_t$")
axes[0].set_ylabel("Density")
axes[0].set_title(r"Forward marginals $q(x_t)$")
axes[0].set_xlim(-8, 8)
axes[0].legend(frameon=False, ncol=2)
style_axes(axes[0])

path_count = 120
paths = np.empty((T + 1, path_count))
paths[0] = sample_mixture(path_count)
for t in range(1, T + 1):
    paths[t] = np.sqrt(1 - beta) * paths[t - 1] + np.sqrt(beta) * rng.normal(size=path_count)

for k in range(path_count):
    pts = np.column_stack([np.arange(T + 1), paths[:, k]])
    segments = np.stack([pts[:-1], pts[1:]], axis=1)
    lc = LineCollection(
        segments,
        cmap="Reds",
        norm=mcolors.Normalize(0, T),
        linewidth=0.8,
        alpha=0.12,
    )
    lc.set_array(np.arange(T))
    axes[1].add_collection(lc)

axes[1].axhline(0, color="black", linewidth=0.8, alpha=0.45)
axes[1].set_xlabel(r"Diffusion step $t$")
axes[1].set_ylabel(r"$x_t$")
axes[1].set_title("Noising trajectories")
axes[1].set_xlim(0, T)
axes[1].set_ylim(-8, 8)
style_axes(axes[1])

sm = plt.cm.ScalarMappable(cmap="Reds", norm=mcolors.Normalize(0, T))
sm.set_array([])
cbar = fig.colorbar(sm, ax=axes, fraction=0.035, pad=0.02)
cbar.set_label("Diffusion step")

fig.savefig(REPORT_FIG_DIR / "diffusion_1d_forward.png", bbox_inches="tight")
plt.show()

# %% [markdown]
# ### Score et processus inverse

# %%
fig, axes = plt.subplots(1, 2, figsize=(10.2, 4.0), constrained_layout=True)
score_steps = [0, 75, 150, 250]
xx = np.linspace(-7.5, 7.5, 37)

for t in score_steps:
    p = mixture_pdf(x_grid, t)
    score = np.gradient(np.log(np.maximum(p, 1e-12)), x_grid)
    p_i = np.interp(xx, x_grid, p)
    s_i = np.clip(np.interp(xx, x_grid, score), -2.5, 2.5)
    y = np.full_like(xx, t / T)
    axes[0].quiver(
        xx, y, s_i, np.zeros_like(s_i), p_i,
        angles="xy", scale_units="xy", scale=10,
        width=0.004,
        color=time_color(t),
        alpha=0.45 + 0.55 * (t / T),
    )

axes[0].set_xlabel(r"$x_t$")
axes[0].set_ylabel(r"Normalized noise level $t/T$")
axes[0].set_title("Score directions toward high density")
axes[0].set_xlim(-8, 8)
axes[0].set_ylim(-0.08, 1.08)
axes[0].set_yticks([0, 0.3, 0.6, 1.0])
axes[0].text(-7.7, 0.03, "data", va="bottom", ha="left", fontsize=16)
axes[0].text(-7.7, 0.97, "noise", va="top", ha="left", fontsize=16)
style_axes(axes[0])

reverse_steps = [250, 150, 75, 25, 0]
for t in reverse_steps:
    axes[1].plot(
        x_grid,
        mixture_pdf(x_grid, t),
        color=time_color_r(t),
        linewidth=3 - 1.4 * (t / T),
        alpha=1 - 0.55 * (t / T),
        label=fr"$t={t}$",
    )
axes[1].annotate("", xy=(-4, 0.11), xytext=(0, 0.39),
                 arrowprops=dict(arrowstyle="->", lw=1.5, color="#1f5a85"))
axes[1].annotate("", xy=(4, 0.23), xytext=(0, 0.39),
                 arrowprops=dict(arrowstyle="->", lw=1.5, color="#1f5a85"))
axes[1].set_xlabel(r"$x_t$")
axes[1].set_ylabel("Density")
axes[1].set_title("Reverse denoising path")
axes[1].set_xlim(-8, 8)
axes[1].legend(frameon=False, ncol=2)
style_axes(axes[1])

fig.savefig(REPORT_FIG_DIR / "diffusion_1d_reverse_score.png", bbox_inches="tight")
plt.show()
